# %% [markdown]
# ## ANALYSING IMDB MOVIES DATA USING PANDAS

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Load data 
md = pd.read_csv('data/movies/IMDB-Movie-Data.csv')

# %%
# Take a look at the data
md
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
md.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
# Fundamental information about the data
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# What is the shape of the data
md.shape
# Out:
# (1000, 12)

# %%
# Basic statistics of the data
md.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
# Some genres, without repetition
md['Genre'].unique
# Out:
# <bound method Series.unique of 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object>

# %%
md
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Columns
md.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# some cols
mv = md[['Rank', 'Title', 'Genre', 'Votes']]

mv
# Out:
#      Rank                    Title                     Genre   Votes
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi  757074
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi  485820
# 2       3                    Split           Horror,Thriller  157606
# 3       4                     Sing   Animation,Comedy,Family   60545
# 4       5            Suicide Squad  Action,Adventure,Fantasy  393727
# ..    ...                      ...                       ...     ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery   27585
# 996   997          Hostel: Part II                    Horror   73152
# 997   998   Step Up 2: The Streets       Drama,Music,Romance   70699
# 998   999             Search Party          Adventure,Comedy    4881
# 999  1000               Nine Lives     Comedy,Family,Fantasy   12435
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## DATA PREPROCESSING

# %%
md.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# Some changes to the names of the columns
# Renaming revenue(millions), runtime
md_ = md.rename(columns={
    'Revenue (Millions)': 'Revenue',
    'Runtime (Minutes)': 'Runtime'
})

# %%
md_.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime  Rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...

# %%
# Dealing with missing values(Nan, na)
md_.dropna()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ## ANALYSIS

# %%
# Most voted movies 
md_['Votes'].max()
# Out:
# 1791916

# %%
# What is the title, director, and other details of the most voted movie
md_[md_['Votes'] == 1791916]
# Out:
#     Rank            Title               Genre  \
# 54    55  The Dark Knight  Action,Crime,Drama
#
#                                           Description           Director  \
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
#                                                Actors  Year  Runtime  Rating  \
# 54  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008      152     9.0
#
#       Votes  Revenue  Metascore
# 54  1791916   533.32       82.0

# %%
# Most rated movie
md_['Rating'].max()
# Out:
# 9.0

# %%
# Meaning the most rated movie is the same as the most voted movie

# %%
# What is the highest runtime
md_['Runtime'].max()
# Out:
# 191

# %%
#the lowest runtime
md_['Runtime'].min()
# Out:
# 66

# %%
# What are the details of the lowest runtime movie
md_[md_['Runtime'] == 66]
# Out:
#      Rank                Title                   Genre  \
# 793   794  Ma vie de Courgette  Animation,Comedy,Drama
#
#                                            Description       Director  \
# 793  After losing his mother, a young boy is sent t...  Claude Barras
#
#                                                 Actors  Year  Runtime  Rating  \
# 793  Gaspard Schlatter, Sixtine Murat, Paulin Jacco...  2016       66     7.8
#
#      Votes  Revenue  Metascore
# 793   4370     0.29       85.0

# %%
# Lets look at the revenue in millions
# Which movie made the highest revenue?
# How much was made?
# Other details of that movie
md_['Revenue'].max()
# Out:
# 936.63

# %%
md_[md_['Revenue'] == 936.63]
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  Runtime  Rating  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015      136     8.1
#
#      Votes  Revenue  Metascore
# 50  661608   936.63       81.0

# %%
# What if we want to pick only movies that are released from 2008 to 2015, 
# have a rating of less than 6.0 but topped in terms of revenue?

md_[(md_['Year'] >= 2008) & (md_['Year'] <= 2015) & (md_['Rating'] < 7.0) & 
    (md_['Revenue'] > md_['Revenue'].quantile(0.95))]
# Out:
#      Rank                                              Title  \
# 400   401                                            Minions
# 547   548                                Alice in Wonderland
# 566   567                     Transformers: Dark of the Moon
# 680   681              The Hunger Games: Mockingjay - Part 1
# 710   711                Transformers: Revenge of the Fallen
# 767   768  Indiana Jones and the Kingdom of the Crystal S...
# 941   942                         The Twilight Saga: Eclipse
#
#                           Genre  \
# 400  Animation,Action,Adventure
# 547    Adventure,Family,Fantasy
# 566     Action,Adventure,Sci-Fi
# 680     Action,Adventure,Sci-Fi
# 710     Action,Adventure,Sci-Fi
# 767    Action,Adventure,Fantasy
# 941     Adventure,Drama,Fantasy
#
#                                            Description          Director  \
# 400  Minions Stuart, Kevin and Bob are recruited by...        Kyle Balda
# ...

# %%
md_.groupby('Director')[['Rating']].mean().head()
# Out:
#                      Rating
# Director
# Aamir Khan              8.5
# Abdellatif Kechiche     7.8
# Adam Leon               6.5
# Adam McKay              7.0
# Adam Shankman           6.3

# %%
md_.groupby('Director')[['Rating']].mean().sort_values(['Rating'], ascending=False).head()
# Out:
#                                   Rating
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Makoto Shinkai                      8.60
# Olivier Nakache                     8.60
# Florian Henckel von Donnersmarck    8.50

# %%
# To check null values row-wise
md_.isnull().sum()
# Out:
# Rank             0
# Title            0
# Genre            0
# Description      0
# Director         0
# Actors           0
# Year             0
# Runtime          0
# Rating           0
# Votes            0
# Revenue        128
# Metascore       64
# dtype: int64

# %%
# Use drop function to drop columns
md_.drop('Metascore', axis=1).head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime  Rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...

# %%
# Drops all rows containing missing data
md_.dropna()
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Drop all columns containing missing data
md_.dropna(axis=1)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
md_.dropna(axis=0, thresh=6)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
revenue_mean = md_['Revenue'].mean()
print("The mean revenue is: ", revenue_mean)
# Out:
# The mean revenue is:  82.95637614678897

# %%
# We can fill the null values with this mean revenue
md_['Revenue'].fillna(revenue_mean, inplace=True)

# %%
md_
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Classify movies based on ratings
def rating_group(rating):
    if rating >= 7.5:
        return 'Good'
    elif rating >= 6.0:
        return 'Average'
    else:
        return 'Bad'

# %%
# Lets apply this function on our movies data
# creating a new variable in the dataset to hold the rating category
md_['Rating_category'] = md_['Rating'].apply(rating_group)

# %%
md_[['Title','Director','Rating','Rating_category']].head(5)
# Out:
#                      Title              Director  Rating Rating_category
# 0  Guardians of the Galaxy            James Gunn     8.1            Good
# 1               Prometheus          Ridley Scott     7.0         Average
# 2                    Split    M. Night Shyamalan     7.3         Average
# 3                     Sing  Christophe Lourdelet     7.2         Average
# 4            Suicide Squad            David Ayer     6.2         Average

# %%
md_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1000 non-null   int64
#  1   Title            1000 non-null   object
#  2   Genre            1000 non-null   object
#  3   Description      1000 non-null   object
#  4   Director         1000 non-null   object
#  5   Actors           1000 non-null   object
#  6   Year             1000 non-null   int64
#  7   Runtime          1000 non-null   int64
#  8   Rating           1000 non-null   float64
#  9   Votes            1000 non-null   int64
#  10  Revenue          1000 non-null   float64
#  11  Metascore        936 non-null    float64
#  12  Rating_category  1000 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 101.7+ KB

# %%
md_.head(39)
# Out:
#     Rank                                    Title                       Genre  \
# 0      1                  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 7      8                                 Mindhorn                      Comedy
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# ...
