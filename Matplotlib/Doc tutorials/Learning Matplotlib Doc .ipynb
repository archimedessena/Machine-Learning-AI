# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig, ax = plt.subplots() 
# Create a figure containing a single axes. 
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]) # Plot some data on the axes.

# %%
fig, my = plt.subplots()
my.plot([30, 40, 50, 60], [-1, -2, -3, -4])

# %%
fig, trans = plt.subplots()
trans.plot([1, 2, 3, -5, -1], [-3, -6, -5, 99, 15])

# %%
fig, num = plt.subplots()
num.plot([4, 5, 7, 9], [10, 20, 40, 1000])

# %%
df = pd.read_csv('data/eng.1.csv')

# %%
df
# Out:
#      Round             Date               Team 1   FT                Team 2
# 0        1   Fri Aug 9 2019         Liverpool FC  4-1       Norwich City FC
# 1        1  Sat Aug 10 2019   West Ham United FC  0-5    Manchester City FC
# 2        1  Sat Aug 10 2019           Burnley FC  3-0        Southampton FC
# 3        1  Sat Aug 10 2019      AFC Bournemouth  1-1   Sheffield United FC
# 4        1  Sat Aug 10 2019    Crystal Palace FC  0-0            Everton FC
# ..     ...              ...                  ...  ...                   ...
# 375     38  Sun Jul 26 2020    Leicester City FC  0-2  Manchester United FC
# 376     38  Sun Jul 26 2020   Manchester City FC  5-0       Norwich City FC
# 377     38  Sun Jul 26 2020  Newcastle United FC  1-3          Liverpool FC
# 378     38  Sun Jul 26 2020       Southampton FC  3-1   Sheffield United FC
# 379     38  Sun Jul 26 2020   West Ham United FC  1-1        Aston Villa FC
#
# [380 rows x 5 columns]

# %%
df['Team 2']
# Out:
# 0           Norwich City FC
# 1        Manchester City FC
# 2            Southampton FC
# 3       Sheffield United FC
# 4                Everton FC
#                ...
# 375    Manchester United FC
# 376         Norwich City FC
# 377            Liverpool FC
# 378     Sheffield United FC
# 379          Aston Villa FC
# Name: Team 2, Length: 380, dtype: object

# %%
plt.plot([40, 50, 7, 90], [445, 678, 345, 123])

# %%
# easiest way to create a figure
fig = plt.figure() # an empty figure with no axes
fig, ax = plt.subplots() # a figure with a single axes

# %%
fig, ax = plt.subplots(2, 2) # a figure with a 2x2 grid of axes

# %%
df.describe()
# Out:
#             Round
# count  380.000000
# mean    19.500000
# std     10.980313
# min      1.000000
# 25%     10.000000
# 50%     19.500000
# 75%     29.000000
# max     38.000000

# %%
df
# Out:
#      Round             Date               Team 1   FT                Team 2
# 0        1   Fri Aug 9 2019         Liverpool FC  4-1       Norwich City FC
# 1        1  Sat Aug 10 2019   West Ham United FC  0-5    Manchester City FC
# 2        1  Sat Aug 10 2019           Burnley FC  3-0        Southampton FC
# 3        1  Sat Aug 10 2019      AFC Bournemouth  1-1   Sheffield United FC
# 4        1  Sat Aug 10 2019    Crystal Palace FC  0-0            Everton FC
# ..     ...              ...                  ...  ...                   ...
# 375     38  Sun Jul 26 2020    Leicester City FC  0-2  Manchester United FC
# 376     38  Sun Jul 26 2020   Manchester City FC  5-0       Norwich City FC
# 377     38  Sun Jul 26 2020  Newcastle United FC  1-3          Liverpool FC
# 378     38  Sun Jul 26 2020       Southampton FC  3-1   Sheffield United FC
# 379     38  Sun Jul 26 2020   West Ham United FC  1-1        Aston Villa FC
#
# [380 rows x 5 columns]
